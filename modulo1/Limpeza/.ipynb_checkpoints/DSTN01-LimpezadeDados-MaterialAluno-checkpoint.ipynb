# %% [markdown]
# # Agenda

# %% [markdown]
# > Data: 19/02/2021<br>
# > Aula: 08 <br>
# > Módulo: 00 <br>

# %% [markdown]
# O objetivo dessa aula é introduzir conceitos sobre limpeza de dados e demonstrar alguns tratamentos.

# %% [markdown]
# ### Limpeza de Dados:

# %%
import pandas as pd
import numpy as np
#!pip install missingno

# %% [markdown]
# # Limpeza de Dados
# referência: https://medium.com/turing-talks/como-fazer-uma-limpeza-de-dados-completa-em-python-7abc9dfc19b8

# %% [markdown]
# ## Por que fazer?

# %% [markdown]
# Em muitos casos trabalhamos com dados com inconstâncias,  incorreto, incompleto, duplicado, formatado incorretamente ou até mesmo que seja irrelevante.

# %% [markdown]
# * Apenas com dados corretos podemos realizar uma análise completa e confiável, e por consequência, todas as outras etapas que dependem da limpeza e dela, serão feitas corretamente. Afinal, esses erros podem gerar um problema em cascata!
#
# * Você não quer estar no meio da sua análise e descobrir que, por exemplo, na coluna 'valor', existam três tipos de moeda Isso seria um exemplo perfeito de dados incorretos.
#
# * Exemplos assim acontecem frequentemente

# %% [markdown]
# ### Lendo seu DataFrame e analisando suas FEATURES

# %% [markdown]
# dataset: imóveis vendidos na cidade de Nova York ao longo de um período de 12 meses, de setembro de 2016 a setembro de 2017.

# %%
# Carregando os dados
nyc_sales = pd.read_csv('nyc-rolling-sales_twentieth.csv')

# %%
nyc_sales.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# 2   39                                  C7   197 EAST 3RD   STREET  ...
# 3   21                                  C4     154 EAST 7TH STREET  ...
# 4   55                                  C2  301 EAST 10TH   STREET  ...
#
#   RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                 5                 0            5              1633
# 1                28                 3           31              4616
# 2                16                 1           17              2212
# 3                10                 0           10              2272
# 4                 6                 0            6              2369
#
#    GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 0               6440       1900                         2
# 1              18690       1900                         2
# 2               7803       1900                         2
# 3               6794       1913                         2
# 4               4615       1900                         2
#
#    BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 0                              C2     6625000  2017-07-19 00:00:00
# 1                              C7         -    2016-12-14 00:00:00
# 2                              C7         -    2016-12-09 00:00:00
# 3                              C4     3936272  2016-09-23 00:00:00
# 4                              C2     8000000  2016-11-17 00:00:00
#
# [5 rows x 22 columns]

# %% [markdown]
# A primeira coisa que observamos é a coluna ```Unnamed: 0```. Devemos removê-la, já que nem nome ela possui. Essa coluna surge geralmente devido a gravação do índice do dataframe como coluna do csv. Se quisermos evitar que um índice de dataframe seja salvo após nossa análise, passamos o parâmetro ```index=False``` para o método ```.to_csv()```.

# %%
nyc_sales.drop(columns = ['Unnamed: 0'], axis=1, inplace = True)

# %%
nyc_sales.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                                  C2
# 1                    2    399   26                                  C7
# 2                    2    399   39                                  C7
# 3                   2B    402   21                                  C4
# 4                   2A    404   55                                  C2
#
#                   ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0            153 AVENUE B                   ...                  5
# 1   234 EAST 4TH   STREET                   ...                 28
# 2   197 EAST 3RD   STREET                   ...                 16
# 3     154 EAST 7TH STREET                   ...                 10
# 4  301 EAST 10TH   STREET                   ...                  6
#
#    COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET GROSS SQUARE FEET  \
# 0                 0            5              1633              6440
# 1                 3           31              4616             18690
# 2                 1           17              2212              7803
# 3                 0           10              2272              6794
# 4                 0            6              2369              4615
#
#   YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 0       1900                          2                              C2
# 1       1900                          2                              C7
# 2       1900                          2                              C7
# 3       1913                          2                              C4
# 4       1900                          2                              C2
#
#   SALE PRICE            SALE DATE
# 0    6625000  2017-07-19 00:00:00
# 1        -    2016-12-14 00:00:00
# 2        -    2016-12-09 00:00:00
# 3    3936272  2016-09-23 00:00:00
# 4    8000000  2016-11-17 00:00:00
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Verificando as colunas

# %%
nyc_sales.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
nyc_sales.shape
# Out:
# (16909, 21)

# %% [markdown]
# Dando uma olhada nos nomes conseguimos ter uma ideia sobre o que se trata cada uma delas, mas não podemos obter todas as informações, afinal algumas possuem uns nomes bem estranhos. Por isso, podemos pesquisar mais detalhadamente a respeito de cada feature do nosso dataset aqui: https://www1.nyc.gov/assets/finance/downloads/pdf/07pdf/glossary_rsf071607.pdf

# %% [markdown]
# ### Verificando os tipos dos dados

# %%
nyc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16909 entries, 0 to 16908
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         16909 non-null  int64
#  1   NEIGHBORHOOD                    16909 non-null  object
#  2   BUILDING CLASS CATEGORY         16909 non-null  object
#  3   TAX CLASS AT PRESENT            16909 non-null  object
#  4   BLOCK                           16909 non-null  int64
#  5   LOT                             16909 non-null  int64
#  6   EASE-MENT                       16909 non-null  object
#  7   BUILDING CLASS AT PRESENT       16909 non-null  object
#  8   ADDRESS                         16909 non-null  object
#  9   APARTMENT NUMBER                16909 non-null  object
#  10  ZIP CODE                        16909 non-null  int64
#  11  RESIDENTIAL UNITS               16909 non-null  int64
#  12  COMMERCIAL UNITS                16909 non-null  int64
#  13  TOTAL UNITS                     16909 non-null  int64
#  14  LAND SQUARE FEET                16909 non-null  object
#  15  GROSS SQUARE FEET               16909 non-null  object
#  16  YEAR BUILT                      16909 non-null  int64
#  17  TAX CLASS AT TIME OF SALE       16909 non-null  int64
#  18  BUILDING CLASS AT TIME OF SALE  16909 non-null  object
#  19  SALE PRICE                      16909 non-null  object
#  20  SALE DATE                       16909 non-null  object
# dtypes: int64(9), object(12)
# memory usage: 2.7+ MB

# %% [markdown]
# Conforme a documentação (link acima) podemos identificar que algumas variáveis que são do tipo numérico estão representadas como ```object```:
# * ```SALE PRICE```
# * ```GROSS SQUARE FEE```
# * ```LAND SQUARE FEE```
# * ```APARTMENT NUMBER```

# %% [markdown]
# Da mesma maneira temos variáveis categóricas que estão como ```int64```:
# * ```BOROUGH```
# * ```BLOCK```
# * ```LOT```
# * ```TAX CLASS AT TIME OF SALE```

# %% [markdown]
# Inclusive, a própria descrição das variáveis nos revela que podemos utilizar BLOCK da seguinte maneira: Manhattan (1), Bronx (2), Brooklyn (3), Queens (4), and Staten Island (5).

# %% [markdown]
# ### Vamos tentar algumas conversões? Para isso iremos tentar as conversões através do método ```.astype()```

# %%
nyc_sales.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %% [markdown]
# ### Convertendo tipo object para float

# %%
nyc_sales['SALE PRICE'] = nyc_sales['SALE PRICE'].astype('float32', errors='ignore')#o método identifica o tipo conforme formato do número
# errors = ignore garantem que se tiver algum missing, mesmo assim será convertido

# %%
nyc_sales['SALE PRICE']
# Out:
# 0        6625000
# 1            -
# 2            -
# 3        3936272
# 4        8000000
#           ...
# 16904        -
# 16905     712500
# 16906     740000
# 16907    1800000
# 16908        -
# Name: SALE PRICE, Length: 16909, dtype: object

# %% [markdown]
# ### Não houve conversão, pois existe um ```-``` no meio das colunas. Isso é um indício de que valores faltosos são representados dessa maneira no nosso dataframe.

# %% [markdown]
# Vamos usar outro método: ```pd.to_nummeric```.

# %%
nyc_sales['SALE PRICE'] = pd.to_numeric(nyc_sales['SALE PRICE'], downcast = 'float', errors='coerce')
nyc_sales['SALE PRICE']
# Out:
# 0        6625000.0
# 1              NaN
# 2              NaN
# 3        3936272.0
# 4        8000000.0
#            ...
# 16904          NaN
# 16905     712500.0
# 16906     740000.0
# 16907    1800000.0
# 16908          NaN
# Name: SALE PRICE, Length: 16909, dtype: float32

# %% [markdown]
# ### Vamos usar um for para converter as demais

# %%
for item in ['GROSS SQUARE FEET', 'LAND SQUARE FEET', 'APARTMENT NUMBER']:
    nyc_sales[item] =  pd.to_numeric(nyc_sales[item], downcast = 'float', errors='coerce')

# %%
nyc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16909 entries, 0 to 16908
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         16909 non-null  int64
#  1   NEIGHBORHOOD                    16909 non-null  object
#  2   BUILDING CLASS CATEGORY         16909 non-null  object
#  3   TAX CLASS AT PRESENT            16909 non-null  object
#  4   BLOCK                           16909 non-null  int64
#  5   LOT                             16909 non-null  int64
#  6   EASE-MENT                       16909 non-null  object
#  7   BUILDING CLASS AT PRESENT       16909 non-null  object
#  8   ADDRESS                         16909 non-null  object
#  9   APARTMENT NUMBER                1156 non-null   float32
#  10  ZIP CODE                        16909 non-null  int64
#  11  RESIDENTIAL UNITS               16909 non-null  int64
#  12  COMMERCIAL UNITS                16909 non-null  int64
#  13  TOTAL UNITS                     16909 non-null  int64
#  14  LAND SQUARE FEET                1731 non-null   float32
#  15  GROSS SQUARE FEET               1621 non-null   float32
#  16  YEAR BUILT                      16909 non-null  int64
#  17  TAX CLASS AT TIME OF SALE       16909 non-null  int64
#  18  BUILDING CLASS AT TIME OF SALE  16909 non-null  object
#  19  SALE PRICE                      13395 non-null  float32
#  20  SALE DATE                       16909 non-null  object
# dtypes: float32(4), int64(9), object(8)
# memory usage: 2.5+ MB

# %% [markdown]
# Perceba que agora aparecem valores NaN no nosso dataframe. Lembrando que não temos mais o sinal -

# %% [markdown]
# o NaN =  significa Not a Number, é um valor especial definido no numpy que pode decodificar um valor faltante, mas ainda assim ser lido como um numeral, pois é definido como float.

# %% [markdown]
# ### AS variáveis categóricas que estão como inteiro iremos converter para ```object```.

# %%
for item in ['BLOCK', 'LOT', 'TAX CLASS AT TIME OF SALE']:
    nyc_sales[item] =  nyc_sales[item].astype('object')

# %%
nyc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16909 entries, 0 to 16908
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         16909 non-null  int64
#  1   NEIGHBORHOOD                    16909 non-null  object
#  2   BUILDING CLASS CATEGORY         16909 non-null  object
#  3   TAX CLASS AT PRESENT            16909 non-null  object
#  4   BLOCK                           16909 non-null  object
#  5   LOT                             16909 non-null  object
#  6   EASE-MENT                       16909 non-null  object
#  7   BUILDING CLASS AT PRESENT       16909 non-null  object
#  8   ADDRESS                         16909 non-null  object
#  9   APARTMENT NUMBER                1156 non-null   float32
#  10  ZIP CODE                        16909 non-null  int64
#  11  RESIDENTIAL UNITS               16909 non-null  int64
#  12  COMMERCIAL UNITS                16909 non-null  int64
#  13  TOTAL UNITS                     16909 non-null  int64
#  14  LAND SQUARE FEET                1731 non-null   float32
#  15  GROSS SQUARE FEET               1621 non-null   float32
#  16  YEAR BUILT                      16909 non-null  int64
#  17  TAX CLASS AT TIME OF SALE       16909 non-null  object
#  18  BUILDING CLASS AT TIME OF SALE  16909 non-null  object
#  19  SALE PRICE                      13395 non-null  float32
#  20  SALE DATE                       16909 non-null  object
# dtypes: float32(4), int64(6), object(11)
# memory usage: 2.5+ MB

# %% [markdown]
# ## map()

# %% [markdown]
# * Usado para substituir cada valor em uma Série por outro valor, que pode ser derivado de uma função, um dicionário ou uma Série.
#
# * mapeará elementos com base nas chaves desse dicionário / série. Os valores ausentes serão registrados como NaN na saída.

# %% [markdown]
# Para as variável BOROUGH, vamos seguir as recomendações da "documentação"

# %%
#documentação informa que: Manhattan (1), Bronx (2), Brooklyn (3), Queens (4), and Staten Island (5).

# %%
nyc_sales['BOROUGH'].unique()
# Out:
# array([1], dtype=int64)

# %%
nyc_sales['BOROUGH'] = nyc_sales['BOROUGH'].map({1: 'Manhattan', 2: 'Bronx', 3: 'Brooklyn', 4: 'Queens', 5: 'Staten Island'})
nyc_sales.head()
# Out:
#      BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT BLOCK LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                   2A   392   6                                  C2
# 1                    2   399  26                                  C7
# 2                    2   399  39                                  C7
# 3                   2B   402  21                                  C4
# 4                   2A   404  55                                  C2
#
#                   ADDRESS  APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0            153 AVENUE B               NaN  ...                  5
# 1   234 EAST 4TH   STREET               NaN  ...                 28
# 2   197 EAST 3RD   STREET               NaN  ...                 16
# 3     154 EAST 7TH STREET               NaN  ...                 10
# 4  301 EAST 10TH   STREET               NaN  ...                  6
#
#    COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 0                 0            5            1633.0             6440.0
# 1                 3           31            4616.0            18690.0
# 2                 1           17            2212.0             7803.0
# 3                 0           10            2272.0             6794.0
# 4                 0            6            2369.0             4615.0
#
#    YEAR BUILT  TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  \
# 0        1900                          2                             C2
# 1        1900                          2                             C7
# 2        1900                          2                             C7
# 3        1913                          2                             C4
# 4        1900                          2                             C2
#
#   SALE PRICE            SALE DATE
# 0  6625000.0  2017-07-19 00:00:00
# 1        NaN  2016-12-14 00:00:00
# 2        NaN  2016-12-09 00:00:00
# 3  3936272.0  2016-09-23 00:00:00
# 4  8000000.0  2016-11-17 00:00:00
#
# [5 rows x 21 columns]

# %% [markdown]
# Compare com o df antes da transformação

# %% [markdown]
# Por fim, temos a coluna ```SALE DATE``` que é uma data, mas que está como string. Vamos convertê-la para data usando a função ```pd.to_datetime```

# %%
nyc_sales['SALE DATE'] = pd.to_datetime(nyc_sales['SALE DATE'], format='%Y-%m-%d')
nyc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16909 entries, 0 to 16908
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         16909 non-null  object
#  1   NEIGHBORHOOD                    16909 non-null  object
#  2   BUILDING CLASS CATEGORY         16909 non-null  object
#  3   TAX CLASS AT PRESENT            16909 non-null  object
#  4   BLOCK                           16909 non-null  object
#  5   LOT                             16909 non-null  object
#  6   EASE-MENT                       16909 non-null  object
#  7   BUILDING CLASS AT PRESENT       16909 non-null  object
#  8   ADDRESS                         16909 non-null  object
#  9   APARTMENT NUMBER                1156 non-null   float32
#  10  ZIP CODE                        16909 non-null  int64
#  11  RESIDENTIAL UNITS               16909 non-null  int64
#  12  COMMERCIAL UNITS                16909 non-null  int64
#  13  TOTAL UNITS                     16909 non-null  int64
#  14  LAND SQUARE FEET                1731 non-null   float32
#  15  GROSS SQUARE FEET               1621 non-null   float32
#  16  YEAR BUILT                      16909 non-null  int64
#  17  TAX CLASS AT TIME OF SALE       16909 non-null  object
#  18  BUILDING CLASS AT TIME OF SALE  16909 non-null  object
#  19  SALE PRICE                      13395 non-null  float32
#  20  SALE DATE                       16909 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float32(4), int64(5), object(11)
# memory usage: 2.5+ MB

# %% [markdown]
# ## Investigação de Inconsistências

# %%
nyc_sales
# Out:
#          BOROUGH             NEIGHBORHOOD  \
# 0      Manhattan            ALPHABET CITY
# 1      Manhattan            ALPHABET CITY
# 2      Manhattan            ALPHABET CITY
# 3      Manhattan            ALPHABET CITY
# 4      Manhattan            ALPHABET CITY
# ...          ...                      ...
# 16904  Manhattan  UPPER WEST SIDE (79-96)
# 16905  Manhattan  UPPER WEST SIDE (79-96)
# 16906  Manhattan  UPPER WEST SIDE (79-96)
# 16907  Manhattan  UPPER WEST SIDE (79-96)
# 16908  Manhattan  UPPER WEST SIDE (79-96)
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT BLOCK  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A   392
# 1      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 2      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 3      07 RENTALS - WALKUP APARTMENTS                                2B   402
# 4      07 RENTALS - WALKUP APARTMENTS                                2A   404
# ...                                            ...                  ...   ...
# 16904  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16905  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16906  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16907  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16908  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
#
#       LOT EASE-MENT BUILDING CLASS AT PRESENT                    ADDRESS  \
# 0       6                                  C2               153 AVENUE B
# 1      26                                  C7      234 EAST 4TH   STREET
# 2      39                                  C7      197 EAST 3RD   STREET
# 3      21                                  C4        154 EAST 7TH STREET
# 4      55                                  C2     301 EAST 10TH   STREET
# ...    ..       ...                       ...                        ...
# 16904  29                                  D4   201 WEST 89TH STREET, 9A
# 16905  29                                  D4  201 WEST 89TH STREET, 10C
# 16906  29                                  D4        201 WEST 89 ST, 10D
# 16907  29                                  D4   201 WEST 89TH STREET, 7G
# 16908  29                                  D4      201 W 89TH STREET, 8E
#
#        APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0                   NaN  ...                  5                 0
# 1                   NaN  ...                 28                 3
# 2                   NaN  ...                 16                 1
# 3                   NaN  ...                 10                 0
# 4                   NaN  ...                  6                 0
# ...                 ...  ...                ...               ...
# 16904               NaN  ...                  0                 0
# 16905               NaN  ...                  0                 0
# 16906               NaN  ...                  0                 0
# 16907               NaN  ...                  0                 0
# 16908               NaN  ...                  0                 0
#
#        TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                5            1633.0             6440.0        1900
# 1               31            4616.0            18690.0        1900
# 2               17            2212.0             7803.0        1900
# 3               10            2272.0             6794.0        1913
# 4                6            2369.0             4615.0        1900
# ...            ...               ...                ...         ...
# 16904            0               NaN                NaN        1925
# 16905            0               NaN                NaN        1925
# 16906            0               NaN                NaN        1925
# 16907            0               NaN                NaN        1925
# 16908            0               NaN                NaN        1925
#
#        TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE SALE PRICE  \
# 0                              2                             C2  6625000.0
# 1                              2                             C7        NaN
# 2                              2                             C7        NaN
# 3                              2                             C4  3936272.0
# 4                              2                             C2  8000000.0
# ...                          ...                            ...        ...
# 16904                          2                             D4        NaN
# 16905                          2                             D4   712500.0
# 16906                          2                             D4   740000.0
# 16907                          2                             D4  1800000.0
# 16908                          2                             D4        NaN
#
#        SALE DATE
# 0     2017-07-19
# 1     2016-12-14
# 2     2016-12-09
# 3     2016-09-23
# 4     2016-11-17
# ...          ...
# 16904 2017-02-08
# 16905 2017-02-13
# 16906 2017-02-13
# 16907 2017-04-27
# 16908 2017-05-04
#
# [16909 rows x 21 columns]

# %% [markdown]
# * Distribuição do dia do mês para checar a conversão de data
#
# * Um dos grandes perigos na conversão de datas é misturar os meses e dias. A função to_datetime() ajuda muito com as mensagens de erro, mesmo assim é boa ideia checar novamente se os dias dos meses extraídos fazem sentido.
#
# * Para fazer isso é possível fazer um gráfico de histograma com os dias do mês. É esperado termos valores distribuídos uniformemente entre 1 e 31, uma vez que não há razão que um dia seja mais comum que outro (exceto 31, pois nem todos os meses tem 31 dias).

# %%
import seaborn as sns
day_of_month = nyc_sales['SALE DATE'].dt.day  # pandas.Series.dt.day 
day_of_month = day_of_month.dropna()#retira os dados faltantes
sns.displot(day_of_month, kde=False, bins=31)

# %% [markdown]
# ### Outilier

# %% [markdown]
# ### Vamos chegar a feature ANO DE CONSTRUÇÃO

# %%
sns.boxplot(x=nyc_sales['YEAR BUILT'])
# Out:
# <AxesSubplot:xlabel='YEAR BUILT'>

# %% [markdown]
# * O gráfico acima mostra ponto o ponto no valor 0, outro  entre  1000 a 1250 e outro próximo a 1800,estes são outliers, pois não estão incluídos na caixa de outra observação. Podem atrapalhar!

# %% [markdown]
# * primeiro passo para saber se um dado é ou não um outlier é o bom senso.
# Isso pode parecer um pouco vago em determinados casos, porém o bom senso é o primeiro caminho que você deve tomar ao abrir um novo dataset, sendo assim é crucial conhecer a história por trás dos seus dados, seja de onde ele foi retirado, as fontes por trás, até talvez qual o parâmetro de medição de alguma feature. Pesquisar sobre o assunto que você está trabalhando também é um trabalho importante para um data scientist.

# %% [markdown]
# ### Eliminando os outiliers

# %% [markdown]
# #### Verificando os pontos que encontramos

# %%
t1 = nyc_sales[(nyc_sales["YEAR BUILT"] == 0 )]
t1
# Out:
#          BOROUGH             NEIGHBORHOOD  \
# 74     Manhattan            ALPHABET CITY
# 76     Manhattan            ALPHABET CITY
# 77     Manhattan            ALPHABET CITY
# 78     Manhattan            ALPHABET CITY
# 87     Manhattan            ALPHABET CITY
# ...          ...                      ...
# 16487  Manhattan  UPPER WEST SIDE (59-79)
# 16488  Manhattan  UPPER WEST SIDE (59-79)
# 16489  Manhattan  UPPER WEST SIDE (59-79)
# 16503  Manhattan  UPPER WEST SIDE (59-79)
# 16524  Manhattan  UPPER WEST SIDE (79-96)
#
#                             BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 74     11A CONDO-RENTALS
# 76      12 CONDOS - WALKUP APARTMENTS                                  2
# 77      12 CONDOS - WALKUP APARTMENTS                                  2
# 78      12 CONDOS - WALKUP APARTMENTS                                  2
# 87      13 CONDOS - ELEVATOR APARTMENTS                                2
# ...                                             ...                  ...
# 16487   47 CONDO NON-BUSINESS STORAGE                                  4
# 16488   47 CONDO NON-BUSINESS STORAGE                                  4
# 16489   47 CONDO NON-BUSINESS STORAGE                                  4
# 16503   47 CONDO NON-BUSINESS STORAGE                                  4
# 16524   04 TAX CLASS 1 CONDOS                                         1C
#
#       BLOCK   LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 74      394  1602
# 76      386  1002                                  R2
# 77      398  1039                                  R2
# 78      405  1211                                  R2
# 87      375  1004                                  R4
# ...     ...   ...       ...                       ...
# 16487  1171  1963                                  RS
# 16488  1171  1978                                  RS
# 16489  1171  2023                                  RS
# 16503  1171  3282                                  RS
# 16524  1224  1102                                  R6
#
#                        ADDRESS  APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 74            183-189 AVENUE B               NaN  ...                  0
# 76       211 EAST 3RD   STREET               NaN  ...                  1
# 77       182 EAST 2ND   STREET               NaN  ...                  1
# 78        511 EAST 11TH STREET               NaN  ...                  1
# 87       754 EAST 6TH   STREET               NaN  ...                  1
# ...                        ...               ...  ...                ...
# 16487  220 RIVERSIDE BOULEVARD             161.0  ...                  0
# 16488  220 RIVERSIDE BOULEVARD             178.0  ...                  0
# 16489  220 RIVERSIDE BOULEVARD               NaN  ...                  0
# 16503  120 RIVERSIDE BOULEVARD               NaN  ...                  0
# 16524   151 WEST 93RD   STREET               NaN  ...                  1
#
#        COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 74                    0            0               NaN                NaN
# 76                    0            1               NaN                NaN
# 77                    0            1               NaN                NaN
# 78                    0            1               NaN                NaN
# 87                    0            1               NaN                NaN
# ...                 ...          ...               ...                ...
# 16487                 0            1               NaN                NaN
# 16488                 0            1               NaN                NaN
# 16489                 0            1               NaN                NaN
# 16503                 0            1               NaN                NaN
# 16524                 0            1               NaN                NaN
#
#        YEAR BUILT  TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  \
# 74              0                          2                             RR
# 76              0                          2                             R2
# 77              0                          2                             R2
# 78              0                          2                             R2
# 87              0                          2                             R4
# ...           ...                        ...                            ...
# 16487           0                          4                             RS
# 16488           0                          4                             RS
# 16489           0                          4                             RS
# 16503           0                          4                             RS
# 16524           0                          1                             R6
#
#       SALE PRICE  SALE DATE
# 74     8058923.0 2017-08-09
# 76      620000.0 2016-12-30
# 77           NaN 2017-02-24
# 78           NaN 2017-07-20
# 87      875000.0 2017-03-31
# ...          ...        ...
# 16487        NaN 2016-12-12
# 16488    40000.0 2016-09-28
# 16489    23500.0 2016-09-28
# 16503    20000.0 2017-06-07
# 16524  3195000.0 2016-12-08
#
# [2180 rows x 21 columns]

# %%
t2 = nyc_sales[(nyc_sales["YEAR BUILT"] >= 1000 ) & (nyc_sales["YEAR BUILT"] <= 1200 )]
t2
# Out:
#        BOROUGH NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 957  Manhattan      CHELSEA  29 COMMERCIAL GARAGES
#
#     TAX CLASS AT PRESENT BLOCK LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 957                    4   799  70                                  G6
#
#       ADDRESS  APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 957  7 AVENUE               NaN  ...                  0                 0
#
#      TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 957            0            2125.0                NaN        1111
#
#      TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE SALE PRICE  \
# 957                          4                             G6  8208750.0
#
#      SALE DATE
# 957 2017-04-21
#
# [1 rows x 21 columns]

# %%
t3 =  nyc_sales[(nyc_sales["YEAR BUILT"] >= 1700 ) & (nyc_sales["YEAR BUILT"] <= 1850 )]
t3
# Out:
#          BOROUGH               NEIGHBORHOOD  \
# 246    Manhattan                    CHELSEA
# 275    Manhattan                    CHELSEA
# 277    Manhattan                    CHELSEA
# 278    Manhattan                    CHELSEA
# 279    Manhattan                    CHELSEA
# 2521   Manhattan                  FINANCIAL
# 3578   Manhattan  GREENWICH VILLAGE-CENTRAL
# 6697   Manhattan               LITTLE ITALY
# 6935   Manhattan            LOWER EAST SIDE
# 10573  Manhattan                       SOHO
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT BLOCK  \
# 246    09 COOPS - WALKUP APARTMENTS                                  2C   720
# 275    09 COOPS - WALKUP APARTMENTS                                   2   744
# 277    09 COOPS - WALKUP APARTMENTS                                   2   744
# 278    09 COOPS - WALKUP APARTMENTS                                   2   744
# 279    09 COOPS - WALKUP APARTMENTS                                   2   744
# 2521   13 CONDOS - ELEVATOR APARTMENTS                                2    72
# 3578   09 COOPS - WALKUP APARTMENTS                                   2   575
# 6697   01 ONE FAMILY DWELLINGS                                        1   471
# 6935   12 CONDOS - WALKUP APARTMENTS                                  2   354
# 10573  01 ONE FAMILY DWELLINGS                                        1   578
#
#         LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 246      34                                  C6
# 275      18                                  C6
# 277      32                                  C6
# 278      32                                  C6
# 279      32                                  C6
# 2521   1008                                  R4
# 3578     72                                  C6
# 6697      2                                  A4
# 6935   1002                                  R2
# 10573    64                                  A4
#
#                              ADDRESS  APARTMENT NUMBER  ...  \
# 246        429 WEST 22ND STREET, 4-G               NaN  ...
# 275         337 WEST 20TH STREET, 4M               NaN  ...
# 277           309 WEST 20TH   STREET               NaN  ...
# 278         309 WEST 20TH STREET, 4R               NaN  ...
# 279    309 WEST 20TH   STREET, BSMNT               NaN  ...
# 2521                 170 JOHN STREET               NaN  ...
# 3578         45 WEST 11TH STREET, 4C               NaN  ...
# 6697           2 CENTRE MARKET PLACE               NaN  ...
# 6935              133 NORFOLK STREET               NaN  ...
# 10573             32 DOMINICK STREET               NaN  ...
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 246                    0                 0            0               NaN
# 275                    0                 0            0               NaN
# 277                   24                 0           24            4600.0
# 278                    0                 0            0               NaN
# 279                    0                 0            0               NaN
# 2521                   1                 0            1               NaN
# 3578                   0                 0            0               NaN
# 6697                   1                 0            1            1016.0
# 6935                   1                 0            1               NaN
# 10573                  1                 0            1            1700.0
#
#        GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 246                  NaN        1850                          2
# 275                  NaN        1850                          2
# 277              12200.0        1850                          2
# 278                  NaN        1850                          2
# 279                  NaN        1850                          2
# 2521                 NaN        1840                          2
# 3578                 NaN        1846                          2
# 6697              3700.0        1800                          1
# 6935                 NaN        1800                          2
# 10573             1699.0        1826                          1
#
#       BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 246                               C6  1750000.0 2017-01-25
# 275                               C6  1100000.0 2017-05-12
# 277                               C6   282000.0 2016-10-19
# 278                               C6   710000.0 2016-09-23
# 279                               C6   282000.0 2016-10-19
# 2521                              R4        NaN 2017-01-04
# 3578                              C6  1300000.0 2016-11-03
# 6697                              A4  7090000.0 2017-03-09
# 6935                              R2        NaN 2016-12-06
# 10573                             A4        NaN 2017-07-31
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Vou remover  os 3 filtros analisados do meu dataframe

# %%
#Resumindo: quero só valores acima de 1800
nyc_sales = nyc_sales[(nyc_sales["YEAR BUILT"] >=1850 )]

# %%
sns.boxplot(x=nyc_sales['YEAR BUILT'])
# Out:
# <AxesSubplot:xlabel='YEAR BUILT'>

# %%
nyc_sales.shape
# Out:
# (14723, 21)

# %% [markdown]
# ### Colunas desnecessárias

# %% [markdown]
# * Algumas colunas podem ser consideradas desnecessárias para nossa análise, isso porque elas não nos passam informações relevantes a respeito do que queremos descobrir
#
# * Você não precisa usar todas as features disponíveis

# %% [markdown]
# ## Tratar dados faltantes

# %% [markdown]
# ### Origem

# %% [markdown]
# Os dados faltosos podem ter diversas origens:
# * Erros de inserção (erro em banco)
# * Erros humanos
# * Erros de medição (sensores)
# * Falhas em Equipamentos

# %% [markdown]
# ### Tratamento

# %% [markdown]
# Quando um dado faltoso surge por meio de um join numa tabela, quase sempre conseguimos preencher o dado faltoso com um valor que faz sentido.
# Ex.: Saque de conta. Nem todos os clientes fazem saque em um mês. Dessa forma, podemos preencher o valor faltoso na coluna de saque para um cliente que não realizou saque como 0.

# %% [markdown]
# Quase nunca a opção de deletar tudo é a melhor, pois podem surgir alguns problemas, como:
# * Introdução de Viés
# * Perda de informação

# %% [markdown]
# Alguns métodos de tratamento de dados faltosos:
# * Deleção
# * Preenchimento com estatísticas (moda para categóricos, mediana ou média para numéricos)
# * Preenchimento por meio de um modelo (KNN, Árvore de Decisão)
# * Preenchimento com regra de negócio

# %% [markdown]
# Algumas boas práticas:
# * Criar Null Categórico para a coluna (funciona para numéricas e categóricas)
# * Não fazer dropna de cara.

# %% [markdown]
# ### Como identificar null em colunas

# %%
nyc_sales.isnull().sum()
# Out:
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                  0
# BLOCK                                 0
# LOT                                   0
# EASE-MENT                             0
# BUILDING CLASS AT PRESENT             0
# ADDRESS                               0
# APARTMENT NUMBER                  13757
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  13082
# GROSS SQUARE FEET                 13106
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                         2831
# SALE DATE                             0
# dtype: int64

# %% [markdown]
# Lembre do tamanho do noso dataframe e comparare a quantidade de dados faltantes

# %% [markdown]
# ## Uma opção é deletar todas as linhas com dados faltantes. Nesse caso seria uma boa opção??

# %% [markdown]
# Opções de Tratamento:
# * Deletar as colunas e Apartment Number, Land Square Feet e Gross Square Feet  e acrescentar uma coluna Null Categórica.
# * Manter a coluna e categorizar (faixas de valores), acrescentando o Null Categórico

# %%
nyc_sales['IS_NULL_APARTMENT_NUMBER'] = False #crio coluna com valor booleano
nyc_sales.loc[nyc_sales['APARTMENT NUMBER'].isnull(), 'IS_NULL_APARTMENT_NUMBER'] = True #nas linhas com valor nulo para coluna 'APARTMENT NUMBER' insira True na mesma linha para a coluna 'IS_NULL_APARTMENT_NUMBER'
# Out:
# <ipython-input-109-bb10bd89ce8f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyc_sales['IS_NULL_APARTMENT_NUMBER'] = False #crio coluna com valor booleano
# C:\Users\Tecnologia\anaconda3\envs\DH\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
nyc_sales.head()
# Out:
#      BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT BLOCK LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                   2A   392   6                                  C2
# 1                    2   399  26                                  C7
# 2                    2   399  39                                  C7
# 3                   2B   402  21                                  C4
# 4                   2A   404  55                                  C2
#
#                   ADDRESS  APARTMENT NUMBER  ...  COMMERCIAL UNITS  \
# 0            153 AVENUE B               NaN  ...                 0
# 1   234 EAST 4TH   STREET               NaN  ...                 3
# 2   197 EAST 3RD   STREET               NaN  ...                 1
# 3     154 EAST 7TH STREET               NaN  ...                 0
# 4  301 EAST 10TH   STREET               NaN  ...                 0
#
#    TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0            5            1633.0             6440.0        1900
# 1           31            4616.0            18690.0        1900
# 2           17            2212.0             7803.0        1900
# 3           10            2272.0             6794.0        1913
# 4            6            2369.0             4615.0        1900
#
#    TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE SALE PRICE  \
# 0                          2                              C2  6625000.0
# 1                          2                              C7        NaN
# 2                          2                              C7        NaN
# 3                          2                              C4  3936272.0
# 4                          2                              C2  8000000.0
#
#    SALE DATE  IS_NULL_APARTMENT_NUMBER
# 0 2017-07-19                      True
# 1 2016-12-14                      True
# 2 2016-12-09                      True
# 3 2016-09-23                      True
# 4 2016-11-17                      True
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Preenchimento de dados -  fillna()

# %% [markdown]
# Uma opção é substituir esses dados pela média da coluna, entretanto, às vezes, a média pode ter sido afetada pelos valores destoantes da coluna, então podemos substituir também pela moda ou mediana. Podemos fazer isso com a função .fillna

# %%
df = pd.DataFrame({
                   'A': [80, np.nan, np.nan, np.nan],
                   'B': [80, np.nan, 76, 67]
                  })
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4301799a738b> in <module>
# ----> 1 df = pd.DataFrame({
#       2                    'A': [80, np.nan, np.nan, np.nan],
#       3                    'B': [80, np.nan, 76, 67]
#       4                   })
#       5 df
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Preencher todos valores faltantes com zero

# %% [markdown]
# ## Preencher com o valor da media da coluna

# %%
# fill na com forward fill (pega o valor presente  e replica para o próximos nulos abaixo dele)
df['A'].fillna(method='ffill') #ou bfill (backward - pega o valor presente  e replica para o próximos nulos acima dele)
# Out:
# 0    80.0
# 1    80.0
# 2    80.0
# 3    80.0
# Name: A, dtype: float64

# %% [markdown]
# ## * Exercício: Faça uma função ou código para filtrar as colunas que estejam preechidas com pelo menos 60% de dados não-nulos

# %% [markdown]
# #### Tempo para pesquisar

# %% [markdown]
# # Análise de Duplicatas

# %% [markdown]
# Duplicatas são registros iguais em sua totalidade ou em um conjunto específico de colunas. Além disso, também podemos ter colunas equivalentes e duplicadas em nosso dataset que não queremos manter, pois gera redundância. E num eventual processo de treinamento de modelo de machine learning isso pode levar superestimação da  performance.

# %% [markdown]
# ### Para remover duplicatas utilizamos a função ```drop_duplicates()```

# %% [markdown]
# ### também requer inplace = True

# %%
# Sem passar nada ele observa se há correspondência exata entre alguma linha e mantém só a primeira linha que ele achou
nyc_sales.drop_duplicates(keep='first')
# podemos ter keep=last (mantém a última linha) ou keep = False (não mantém nenhuma)
# Out:
#         BOROUGH             NEIGHBORHOOD  \
# 0      Manhatan            ALPHABET CITY
# 1      Manhatan            ALPHABET CITY
# 2      Manhatan            ALPHABET CITY
# 3      Manhatan            ALPHABET CITY
# 4      Manhatan            ALPHABET CITY
# ...         ...                      ...
# 16904  Manhatan  UPPER WEST SIDE (79-96)
# 16905  Manhatan  UPPER WEST SIDE (79-96)
# 16906  Manhatan  UPPER WEST SIDE (79-96)
# 16907  Manhatan  UPPER WEST SIDE (79-96)
# 16908  Manhatan  UPPER WEST SIDE (79-96)
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT BLOCK  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A   392
# 1      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 2      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 3      07 RENTALS - WALKUP APARTMENTS                                2B   402
# 4      07 RENTALS - WALKUP APARTMENTS                                2A   404
# ...                                            ...                  ...   ...
# 16904  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16905  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16906  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16907  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16908  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
#
#       LOT EASE-MENT BUILDING CLASS AT PRESENT                    ADDRESS  \
# 0       6                                  C2               153 AVENUE B
# 1      26                                  C7      234 EAST 4TH   STREET
# 2      39                                  C7      197 EAST 3RD   STREET
# 3      21                                  C4        154 EAST 7TH STREET
# 4      55                                  C2     301 EAST 10TH   STREET
# ...    ..       ...                       ...                        ...
# 16904  29                                  D4   201 WEST 89TH STREET, 9A
# 16905  29                                  D4  201 WEST 89TH STREET, 10C
# 16906  29                                  D4        201 WEST 89 ST, 10D
# 16907  29                                  D4   201 WEST 89TH STREET, 7G
# 16908  29                                  D4      201 W 89TH STREET, 8E
#
#        APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0                   NaN     10009                  5                 0
# 1                   NaN     10009                 28                 3
# 2                   NaN     10009                 16                 1
# 3                   NaN     10009                 10                 0
# 4                   NaN     10009                  6                 0
# ...                 ...       ...                ...               ...
# 16904               NaN     10024                  0                 0
# 16905               NaN     10024                  0                 0
# 16906               NaN     10024                  0                 0
# 16907               NaN     10024                  0                 0
# 16908               NaN     10024                  0                 0
#
#        TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                5            1633.0             6440.0        1900
# 1               31            4616.0            18690.0        1900
# 2               17            2212.0             7803.0        1900
# 3               10            2272.0             6794.0        1913
# 4                6            2369.0             4615.0        1900
# ...            ...               ...                ...         ...
# 16904            0               NaN                NaN        1925
# 16905            0               NaN                NaN        1925
# 16906            0               NaN                NaN        1925
# 16907            0               NaN                NaN        1925
# 16908            0               NaN                NaN        1925
#
#       TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                             2                             C2   6625000.0
# 1                             2                             C7         NaN
# 2                             2                             C7         NaN
# 3                             2                             C4   3936272.0
# 4                             2                             C2   8000000.0
# ...                         ...                            ...         ...
# 16904                         2                             D4         NaN
# 16905                         2                             D4    712500.0
# 16906                         2                             D4    740000.0
# 16907                         2                             D4   1800000.0
# 16908                         2                             D4         NaN
#
#        SALE DATE  IS_NULL_APARTMENT_NUMBER
# 0     2017-07-19                      True
# 1     2016-12-14                      True
# 2     2016-12-09                      True
# 3     2016-09-23                      True
# 4     2016-11-17                      True
# ...          ...                       ...
# 16904 2017-02-08                      True
# 16905 2017-02-13                      True
# 16906 2017-02-13                      True
# 16907 2017-04-27                      True
# 16908 2017-05-04                      True
#
# [14546 rows x 22 columns]

# %%
# O parâmetro subset nos da a liberdade de procurar duplicatas apenas em um conjunto de colunas
nyc_sales.drop_duplicates(subset= ['BOROUGH','NEIGHBORHOOD'])
# Out:
#         BOROUGH               NEIGHBORHOOD  \
# 0      Manhatan              ALPHABET CITY
# 204    Manhatan                    CHELSEA
# 1007   Manhatan                  CHINATOWN
# 1122   Manhatan               CIVIC CENTER
# 1445   Manhatan                    CLINTON
# 1791   Manhatan               EAST VILLAGE
# 1969   Manhatan                    FASHION
# 2090   Manhatan                  FINANCIAL
# 2586   Manhatan                   FLATIRON
# 3059   Manhatan                   GRAMERCY
# 3533   Manhatan  GREENWICH VILLAGE-CENTRAL
# 4171   Manhatan     GREENWICH VILLAGE-WEST
# 4797   Manhatan             HARLEM-CENTRAL
# 5644   Manhatan                HARLEM-EAST
# 5988   Manhatan               HARLEM-UPPER
# 6129   Manhatan                HARLEM-WEST
# 6167   Manhatan                     INWOOD
# 6286   Manhatan              JAVITS CENTER
# 6327   Manhatan                   KIPS BAY
# 6698   Manhatan               LITTLE ITALY
# 6738   Manhatan            LOWER EAST SIDE
# 7040   Manhatan           MANHATTAN VALLEY
# 7274   Manhatan                MIDTOWN CBD
# 7474   Manhatan               MIDTOWN EAST
# 8892   Manhatan               MIDTOWN WEST
# 9810   Manhatan        MORNINGSIDE HEIGHTS
# 9882   Manhatan                MURRAY HILL
# 10503  Manhatan           ROOSEVELT ISLAND
# 10571  Manhatan                       SOHO
# 10887  Manhatan                SOUTHBRIDGE
# 11029  Manhatan                    TRIBECA
# 11684  Manhatan    UPPER EAST SIDE (59-79)
# 13420  Manhatan    UPPER EAST SIDE (79-96)
# 15010  Manhatan   UPPER EAST SIDE (96-110)
# 15065  Manhatan    UPPER WEST SIDE (59-79)
# 16504  Manhatan    UPPER WEST SIDE (79-96)
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT BLOCK  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A   392
# 204    01 ONE FAMILY DWELLINGS                                        1   766
# 1007   07 RENTALS - WALKUP APARTMENTS                                 2   162
# 1122   07 RENTALS - WALKUP APARTMENTS                                2B   175
# 1445   07 RENTALS - WALKUP APARTMENTS                                 2  1053
# 1791   02 TWO FAMILY DWELLINGS                                        1   436
# 1969   07 RENTALS - WALKUP APARTMENTS                                 2   762
# 2090   08 RENTALS - ELEVATOR APARTMENTS                               2    27
# 2586   08 RENTALS - ELEVATOR APARTMENTS                               2   844
# 3059   02 TWO FAMILY DWELLINGS                                        1   873
# 3533   01 ONE FAMILY DWELLINGS                                        1   525
# 4171   01 ONE FAMILY DWELLINGS                                        1   584
# 4797   01 ONE FAMILY DWELLINGS                                        1  1829
# 5644   01 ONE FAMILY DWELLINGS                                        1  1625
# 5988   01 ONE FAMILY DWELLINGS                                        1  2058
# 6129   01 ONE FAMILY DWELLINGS                                        1  2071
# 6167   01 ONE FAMILY DWELLINGS                                        1  2215
# 6286   02 TWO FAMILY DWELLINGS                                        1   733
# 6327   02 TWO FAMILY DWELLINGS                                        1   924
# 6698   07 RENTALS - WALKUP APARTMENTS                                 2   480
# 6738   02 TWO FAMILY DWELLINGS                                        1   288
# 7040   03 THREE FAMILY DWELLINGS                                      1  1847
# 7274   10 COOPS - ELEVATOR APARTMENTS                                 2  1293
# 7474   01 ONE FAMILY DWELLINGS                                        1  1322
# 8892   07 RENTALS - WALKUP APARTMENTS                                2B  1009
# 9810   07 RENTALS - WALKUP APARTMENTS                                 2  1993
# 9882   01 ONE FAMILY DWELLINGS                                        1   893
# 10503  10 COOPS - ELEVATOR APARTMENTS                                 2  1373
# 10571  01 ONE FAMILY DWELLINGS                                        1   490
# 10887  08 RENTALS - ELEVATOR APARTMENTS                               2    92
# 11029  09 COOPS - WALKUP APARTMENTS                                  2C   193
# 11684  01 ONE FAMILY DWELLINGS                                        1  1380
# 13420  01 ONE FAMILY DWELLINGS                                        1  1491
# 15010  07 RENTALS - WALKUP APARTMENTS                                 2  1610
# 15065  01 ONE FAMILY DWELLINGS                                        1  1126
# 16504  01 ONE FAMILY DWELLINGS                                        1  1197
#
#        LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0        6                                  C2            153 AVENUE B
# 204     13                                  A9  251 WEST 16TH   STREET
# 1007    15                                  C7          28 MOTT STREET
# 1122    19                                  C7         41 WHITE STREET
# 1445     4                                  C7       602 10TH   AVENUE
# 1791     1                                  S2            138 1 AVENUE
# 1969    17                                  C4    331 WEST 38TH STREET
# 2090     9                                  D5          63 WALL STREET
# 2586     8                                  D6    9 EAST 16TH   STREET
# 3059    31                                  S2  141 EAST 17TH   STREET
# 3533    34                                  S1     168 THOMPSON STREET
# 4171    31                                  A4       75 BEDFORD STREET
# 4797   125                                  A4     221 WEST 113 STREET
# 5644   101                                  A9   101B EAST 97TH STREET
# 5988     6                                  A9     465 WEST 141 STREET
# 6129   141                                  A9   516 WEST 140TH STREET
# 6167   510                                  A5   49 MARBLE HILL AVENUE
# 6286    63                                  S2    448 WEST 36TH STREET
# 6327    11                                  B9  313 EAST 18TH   STREET
# 6698     1                                  C7       388 BROOME STREET
# 6738    36                                  S2        527 GRAND STREET
# 7040    11                                  C0     317 WEST 112 STREET
# 7274    37                                  D4    470 PARK AVENUE, 11B
# 7474     8                                  A4  213 EAST 48TH   STREET
# 8892    16                                  C7    129 WEST 56TH STREET
# 9810    82                                  C7           3151 BROADWAY
# 9882    71                                  A4  132 EAST 38TH   STREET
# 10503    1                                  D4           40 RIVER ROAD
# 10571   28                                  A7      40 SULLIVAN STREET
# 10887    3                                  D5  165-167 WILLIAM STREET
# 11029   15                                  C8      38 WHITE STREET, 2
# 11684  143                                  A7     58 EAST 66TH STREET
# 13420   43                                  A4   62 EAST 80TH   STREET
# 15010    9                                  C1   21-23 EAST 104 STREET
# 15065   11                                  A4     43 WEST 73RD STREET
# 16504   18                                  A9   35 WEST 83RD   STREET
#
#        APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0                   NaN     10009                  5                 0
# 204                 NaN     10011                  1                 0
# 1007                NaN     10013                 17                 1
# 1122                NaN     10013                  7                 1
# 1445                NaN     10036                 14                 1
# 1791                NaN     10009                  2                 1
# 1969                NaN     10018                 16                 2
# 2090                NaN     10005                476                 6
# 2586                NaN     10003                 15                 1
# 3059                NaN     10003                  2                 1
# 3533                NaN     10012                  1                 1
# 4171                NaN     10014                  1                 0
# 4797                NaN     10026                  1                 0
# 5644                NaN     10029                  1                 0
# 5988                NaN     10031                  1                 0
# 6129                NaN     10031                  1                 0
# 6167                NaN     10463                  1                 0
# 6286                NaN     10018                  2                 1
# 6327                NaN     10003                  2                 0
# 6698                NaN     10013                 26                 3
# 6738                NaN     10002                  2                 1
# 7040                NaN     10026                  3                 0
# 7274                NaN     10022                  0                 0
# 7474                NaN     10017                  1                 0
# 8892                NaN     10019                  8                 1
# 9810                NaN     10027                 21                 2
# 9882                NaN     10016                  1                 0
# 10503               NaN     10044                  0                 0
# 10571               NaN     10013                  1                 0
# 10887               NaN     10038                 12                 1
# 11029               NaN     10013                  0                 0
# 11684               NaN     10065                  1                 0
# 13420               NaN     10075                  1                 0
# 15010               NaN     10029                 32                 0
# 15065               NaN     10023                  1                 0
# 16504               NaN     10024                  1                 0
#
#        TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                5            1633.0             6440.0        1900
# 204              1            1360.0             2736.0        1910
# 1007            18            2307.0             8577.0        1920
# 1122             8            2633.0            12000.0        1915
# 1445            15            2217.0             9475.0        1910
# 1791             3            1200.0             3360.0        1900
# 1969            18            2475.0             9690.0        1920
# 2090           482           17623.0           400531.0        1929
# 2586            16            4600.0            30680.0        1900
# 3059             3            2300.0             6720.0        1920
# 3533             2            1350.0             5807.0        1900
# 4171             1            1640.0             2400.0        1901
# 4797             1            1682.0             2727.0        1910
# 5644             1             847.0             1472.0        1925
# 5988             1            1799.0             6264.0        1920
# 6129             1            1499.0             2845.0        1899
# 6167             1            1219.0             1224.0        1920
# 6286             3            2469.0             4747.0        1910
# 6327             2            1840.0             2880.0        1910
# 6698            29            1792.0            14931.0        1900
# 6738             3            1238.0             3714.0        1910
# 7040             3            1682.0             3333.0        1900
# 7274             0               NaN                NaN        1916
# 7474             1            1665.0             3060.0        1899
# 8892             9            2092.0             8180.0        1920
# 9810            23            4158.0            16377.0        1905
# 9882             1             495.0             1920.0        1910
# 10503            0               NaN                NaN        1975
# 10571            1            2100.0             4607.0        2015
# 10887           13            3480.0            31073.0        1908
# 11029            0               NaN                NaN        1915
# 11684            1            2008.0             9600.0        1922
# 13420            1            1839.0             5280.0        1899
# 15010           32            5046.0            26100.0        1930
# 15065            1            2146.0             6485.0        1910
# 16504            1            1600.0             3750.0        1901
#
#       TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE   SALE PRICE  \
# 0                             2                             C2    6625000.0
# 204                           1                             A9          NaN
# 1007                          2                             C7          NaN
# 1122                          2                             C7  141500000.0
# 1445                          2                             C7          NaN
# 1791                          1                             S2    3000000.0
# 1969                          2                             C4          NaN
# 2090                          2                             D5  239114608.0
# 2586                          2                             D6          NaN
# 3059                          1                             S2    5300000.0
# 3533                          1                             S1    9999999.0
# 4171                          1                             A4    7800000.0
# 4797                          1                             A4          NaN
# 5644                          1                             A9          NaN
# 5988                          1                             A9          NaN
# 6129                          1                             A9    2260000.0
# 6167                          1                             A5     635000.0
# 6286                          1                             S2    6100000.0
# 6327                          1                             B9    4600000.0
# 6698                          2                             C7   15200000.0
# 6738                          1                             S2          NaN
# 7040                          1                             C0    3075000.0
# 7274                          2                             D4    2000000.0
# 7474                          1                             A4    5000000.0
# 8892                          2                             C7          NaN
# 9810                          2                             C7          NaN
# 9882                          1                             A4    3850000.0
# 10503                         2                             D4    4127983.0
# 10571                         1                             A7          NaN
# 10887                         2                             D5   19000000.0
# 11029                         2                             C8    3700000.0
# 11684                         1                             A7   24175000.0
# 13420                         1                             A4          NaN
# 15010                         2                             C1    1741816.0
# 15065                         1                             A4   15500000.0
# 16504                         1                             A9          NaN
#
#        SALE DATE  IS_NULL_APARTMENT_NUMBER
# 0     2017-07-19                      True
# 204   2017-01-06                      True
# 1007  2017-06-16                      True
# 1122  2017-07-13                      True
# 1445  2016-11-04                      True
# 1791  2017-08-31                      True
# 1969  2016-12-23                      True
# 2090  2016-09-30                      True
# 2586  2017-01-30                      True
# 3059  2017-08-03                      True
# 3533  2016-11-22                      True
# 4171  2017-08-15                      True
# 4797  2016-12-15                      True
# 5644  2017-03-07                      True
# 5988  2016-12-15                      True
# 6129  2016-10-19                      True
# 6167  2017-08-18                      True
# 6286  2017-01-13                      True
# 6327  2016-09-02                      True
# 6698  2016-11-30                      True
# 6738  2017-02-14                      True
# 7040  2017-03-20                      True
# 7274  2016-11-28                      True
# 7474  2017-02-15                      True
# 8892  2016-12-13                      True
# 9810  2016-09-21                      True
# 9882  2017-07-10                      True
# 10503 2016-11-01                      True
# 10571 2017-07-14                      True
# 10887 2017-02-10                      True
# 11029 2017-04-06                      True
# 11684 2017-02-10                      True
# 13420 2017-04-01                      True
# 15010 2017-06-29                      True
# 15065 2017-01-12                      True
# 16504 2017-01-31                      True

# %% [markdown]
# ## Remoção de Colunas Constantes

# %% [markdown]
# Uma coluna constante não agrega em informação para nenhuma análise. Geralmente excluímos.

# %%
# podemos varrer as colunas com um foor lop e identificar quais colunas possuem apenas um valor possível de preenchimento
colunas_constantes = []
for col in nyc_sales.columns:
    if len(nyc_sales[col].unique()) == 1:    #retorno booleano
        colunas_constantes.append(col)
    else:
        print(f'{col} OK')
# Out:
# NEIGHBORHOOD OK
# BUILDING CLASS CATEGORY OK
# TAX CLASS AT PRESENT OK
# BLOCK OK
# LOT OK
# BUILDING CLASS AT PRESENT OK
# ADDRESS OK
# APARTMENT NUMBER OK
# ZIP CODE OK
# RESIDENTIAL UNITS OK
# COMMERCIAL UNITS OK
# TOTAL UNITS OK
# LAND SQUARE FEET OK
# GROSS SQUARE FEET OK
# YEAR BUILT OK
# TAX CLASS AT TIME OF SALE OK
# BUILDING CLASS AT TIME OF SALE OK
# SALE PRICE OK
# SALE DATE OK
# IS_NULL_APARTMENT_NUMBER OK

# %%
colunas_constantes
# Out:
# ['BOROUGH', 'EASE-MENT']

# %% [markdown]
# ## Remoção Por baixa variância

# %% [markdown]
# Variância é uma medida do quão espalhados estão os seus dados ao redor da média.

# %% [markdown]
# <img src="https://www.portalaction.com.br/sites/default/files/resize/EstatisticaBasica/figuras/ebe2.2-650x132.png" height=350 widht=150>

# %% [markdown]
# Os dados do conjunto 2 estão mais dispersos e, dessa maneira, dizemos que este possui maior variância em relação ao primeiro conjunto.

# %% [markdown]
# Quando coletamos dados para utilizar em um modelo de machine learning, é interessante que eles possuam um nível mínimo de variância. Dessa forma, iremos filtrar colunas cuja variância seja muito próxima de zero (lembre-se de que já eliminamos aquelas que possuíam todos os elementos iguais).

# %% [markdown]
# O conjunto 1 abaixo possui um único valor diferente (6) que varia 1 unidade em relação aos demais.  O conjunto 2, por sua vez, também possui apenas um valor diferente dos demais (600) e 100 unidades a mais que os demais. Proporcionalmente, os dois conjuntos variam na mesma escala. Mas pelo cálculo da variância, elas são diferentes.

# %% [markdown]
# ### Antes de tudo nós precisamos escalar nossos dados antes de calcular a variância. Vamos fazer isso utilizando o MinMaxScaler do Scikit-Learn.

# %% [markdown]
# ### Verificando variância das colunas numéricas

# %%
variaveis_numericas_nyc = nyc_sales.select_dtypes(include=['int', 'float'])
variaveis_numericas_escaladas_nyc = minmax.fit_transform(variaveis_numericas_nyc) # aplicando escalonamento - default=(0, 1)

# %%
variaveis_numericas_escaladas_nyc = pd.DataFrame(variaveis_numericas_escaladas_nyc, columns=variaveis_numericas_nyc.columns)

# %% [markdown]
# Não queremos variância muito próximas de zero, então vamos filtrar variancia > 0.001

# %% [markdown]
# #### Ou usar um for para percorrer as colunas muméricas

# %%
listLowVariance = []
for col in variaveis_numericas_escaladas_nyc.columns:
    if np.var(variaveis_numericas_escaladas_nyc[col]) > 0.001:
        print(f'{col} possui variância considerável')
    else:
        print(f'{col} possui baixa variância')
        listLowVariance.append(col)
# Out:
# APARTMENT NUMBER possui variância considerável
# LAND SQUARE FEET possui variância considerável
# GROSS SQUARE FEET possui variância considerável

# %%
listLowVariance
# Out:
# ['RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS', 'SALE PRICE']
